# %%
import pandas as pd
import time
import requests
import json

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys


driver = webdriver.Chrome()
driver.get("https://www.gsmarena.com/")
print("open chrome")
time.sleep(10)
ad_baner_close = driver.find_element(By.ID,"clever_73756_topscroll_close")
ad_baner_close.click()
search_input = driver.find_element(By.ID, "topsearch-text")
search_input.send_keys("Samsung s23")
search_input.send_keys(Keys.ENTER)
productId = []

for i in range(1,5):
    product_xpath = f'//*[@id="review-body"]/div/ul/li[{i}]/a'
    product_link = driver.find_element(By.XPATH,product_xpath)
    link_productId_1 = product_link.get_attribute("href")
    prodcutId_1 = link_productId_1[link_productId_1.find("-")+1:link_productId_1.rfind(".")]
    print(prodcutId_1)
    productId.append((int(prodcutId_1),link_productId_1))
    
print(productId)

for item in productId:
    driver.get(item[1])
    print(item[0])
    product_review_link = driver.find_element(By.XPATH,'//*[@id="user-comments"]/h2/a')
    driver.get(product_review_link.get_attribute("href"))
    get_last_page_button = driver.find_element(By.XPATH,'//*[@id="user-pages"]/a[2]')
    pageSize = int(get_last_page_button.text)
    df = pd.DataFrame(columns= ['Date', 'Name', 'Text'])

    for i in range(1,pageSize):
        api_link = f"https://www.gsmarena.com/comments-json.php3?idType=1&idItem={item[0]}&nSort=1&sSearch=&iPage={str(i)}"
        response = requests.get(api_link)
        print(api_link)
        decoded_response = response.content.decode('UTF-8')
        data = json.loads(decoded_response)
        if 'items' in data:
            for review in data['items']:
                name = review.get('nickname')
                text = review.get('text')
                date = review.get('date')
                df.loc[-1] = [date, name, text]  # adding a row
                df.index = df.index + 1  # shifting index
                df = df.sort_index()  # s
            # Process the data as needed
    df.head()
    file_path = f'{item[0]}.xlsx'
    df.to_excel(file_path, index=False)  # Set index=False to exclude row numbers
    print(f"DataFrame saved to {file_path}")
# Out:
# open chrome
# 12024
# 12082
# 12520
# 12083
# [(12024, 'https://www.gsmarena.com/samsung_galaxy_s23_ultra-12024.php'), (12082, 'https://www.gsmarena.com/samsung_galaxy_s23-12082.php'), (12520, 'https://www.gsmarena.com/samsung_galaxy_s23_fe-12520.php'), (12083, 'https://www.gsmarena.com/samsung_galaxy_s23+-12083.php')]
# 12024
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=1
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=2
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=3
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=4
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=5
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=6
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=7
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=8
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=9
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=10
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=11
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=12
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=13
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=14
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=15
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=16
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=17
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=18
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=19
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=20
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=21
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=22
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=23
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=24
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=25
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=26
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=27
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=28
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=29
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=30
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=31
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=32
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=33
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=34
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=35
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=36
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=37
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=38
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=39
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=40
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=41
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=42
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=43
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=44
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=45
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=46
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=47
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=48
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=49
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=50
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=51
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=52
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=53
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=54
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=55
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=56
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage=57
# https://www.gsmarena.com/comments-json.php3?idType=1&idItem=12024&nSort=1&sSearch=&iPage